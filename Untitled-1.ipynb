# %%
import pandas as pd

# %%
df=pd.read_excel("E:\\python\\hate speech tracker.xlsx")
df
# Out:
#                    Person/ Group delivering the speech  \
# 0                                        BJP councilor
# 1     Far-right social media influencer Harsha Thakur
# 2                 Gau Raksha Dal leader Bittu Bajrangi
# 3         Unknown- Antarrashtriya Hindu Parishad (AHP)
# 4             Hindu Rashtra Sena Chief Dhananjay Desai
# ..                                                 ...
# 146   Union minister and BJP leader  Shobha Karandlaje
# 147   ‘right-wing’ activist Kajal Shingala alias Ka...
# 148                    Complaint filed by Divya Yadav
# 149                       Hindu monk Pramahans Acharya
# 150                         Celebration for ram temple
#
#      Date of event/ date of report         place   Is it hate speech?   \
# 0                       2024-04-23      Rajasthan                 True
# 1                       2024-04-22    Maharashtra                 True
# 2                       2024-04-14        Haryana                 True
# ...

# %%
df['place '].str.strip()
df['place']=df['place '].str.strip()
df
# Out:
#                    Person/ Group delivering the speech  \
# 0                                        BJP councilor
# 1     Far-right social media influencer Harsha Thakur
# 2                 Gau Raksha Dal leader Bittu Bajrangi
# 3         Unknown- Antarrashtriya Hindu Parishad (AHP)
# 4             Hindu Rashtra Sena Chief Dhananjay Desai
# ..                                                 ...
# 146   Union minister and BJP leader  Shobha Karandlaje
# 147   ‘right-wing’ activist Kajal Shingala alias Ka...
# 148                    Complaint filed by Divya Yadav
# 149                       Hindu monk Pramahans Acharya
# 150                         Celebration for ram temple
#
#      Date of event/ date of report         place   Is it hate speech?   \
# 0                       2024-04-23      Rajasthan                 True
# 1                       2024-04-22    Maharashtra                 True
# 2                       2024-04-14        Haryana                 True
# ...
